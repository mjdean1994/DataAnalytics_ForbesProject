# %% [markdown]
# # Vehicle Recall Data - David's Work with CMPL and Mileage
# ### Initial Questions
# * What Make/Model is being recalled?
#     * See Fig 1, Fig 2, and Fig 3
#     * Honda, Ford, Blue Bird most common
# * What specific problems led to the recall?
#     * Most common by far is airbags (Fig 5)
# * Is this correlated to an increase in defects or better QA?
# * At what mileage did we start seeing the problem?
#     * Average Miles at Failure: 68334.08213141191
# * Did an increase in complaints lead to a recall?
#     * Generally, as the number of recalls go up, the number of complaints also go up (Fig 4)

# %% [markdown]
# # Required Code
#
# This is the code required to load the datasets we need

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
import re

data_path = 'data'
fields_path = 'fields'

# Read and parse a file containing column names for a dataset.
# Returns a list of strings (the column names).
def load_column_names(columns_file_name):
    file = open(columns_file_name)
    column_names = []
    readingFields = False
    for line in file:
        if readingFields:
            if re.match('^[0-9]', line):
                split_line = line.split()
                column_names.append(split_line[1])
        elif line.startswith('Field#'):
            readingFields = True
    file.close()
    return column_names
#}

# Load a dataest by its abbreviated names (ex: RCL).
def load_data_file(name, encoding):
    
    # Read the column names from a separate file.
    fields_file_name = fields_path + '/' + name + '.txt';
    names = load_column_names(fields_file_name)
    
    # Read the data from a CSV file.
    data_file_name = 'FLAT_' + name + '.txt';
    df = pd.read_csv(data_path + '/' + data_file_name,
                     delimiter='\t', header=None, encoding=encoding, names=names)
    
    return df
#}

print("done")
# Out:
# done

# %% [markdown]
# # Data Exploration

# %%
# Load complaints dataset.
cmpl_df = load_data_file('CMPL', encoding='iso-8859-1');

# Load recalls dataset.
rcl_df = load_data_file('RCL', encoding='latin1');
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (15,22,26,32,33,34,35,36,38,39,40,41,42,43,44,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
#plt.figure()
#cmpl_df['MILES'].plot(kind='box')
#plt.gcf()
#cmpl_df['MILES'].describe()

col_miles = cmpl_df['MILES'].dropna();


#cmpl_df[(cmpl_df['MILES'] >= 99) & (cmpl_df['MILES'] <= 101)]["MILES"]
#cmpl_df[(cmpl_df['MILES'] < 0)]["MILES"]

clean_miles = cmpl_df[(cmpl_df["MILES"] >= 0) & (cmpl_df["MILES"] < 300000)]["MILES"]

clean_miles = clean_miles / 1000;

clean_df = cmpl_df[(cmpl_df["MILES"] >= 0) & (cmpl_df["MILES"] < 300000)]

#clean_miles = cmpl_df['VEH_SPEED'].dropna();
#clean_miles = pd.to_numeric(cmpl_df['NUM_CYLS'], errors='coerce').dropna()
#clean_miles = clean_miles[(clean_miles >= 2) & (clean_miles <= 10)]
#clean_miles = cmpl_df[(cmpl_df['VEH_SPEED'] >= 140) & (cmpl_df['VEH_SPEED'] < 1000)]['VEH_SPEED']

clean_miles = cmpl_df['DEATHS']
clean_miles = clean_miles[(clean_miles > 10) & (clean_miles <= 99)]


plt.figure()
clean_miles.hist(bins=20, color='#FF5500')
#clean_df.plot(kind='scatter', x='MILES', y='OCCURENCES');
plt.title("Fig 7 - Milage at Failure", y=1.1)
plt.ylabel('Number of Failures', fontsize=12)
plt.xlabel('Miles at Failure (thousands)', fontsize=12)
plt.gcf()

# %%
clean_df = cmpl_df[(cmpl_df["MILES"] >= 0) & (cmpl_df["MILES"] < 300000)]

plt.figure()
clean_df.plot(kind='scatter', x='MILES', y='OCCURENCES');
plt.title("Fig 5 - Number of Failures per Mile at Failure")
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Miles at Failure', fontsize=12)
plt.gcf()

#create_box_graph(clean_df, col_x='MILES', col_y='OCCURENCES', num_bins=10);

# %%
import math;
matplotlib.style.use('ggplot')

curr_df = cmpl_df[["MILES", "OCCURENCES"]].dropna();
#curr_df = [(curr_df["MILES"] >= 980000) & (curr_df["MILES"] < 1000000)]

numBins = 20 + 1;
bins = py.linspace(0, 200000, numBins);
#bins = py.linspace(0, 50000, numBins);
#bin_df = pd.cut(curr_df['MILES'], bins, labels=bins[1:])

#print(bin_df)

binLabels = bins[1:];
binLabels = list(map(lambda x: math.floor(x / 1000), binLabels));
    
    
plt.figure()
curr_df.groupby(pd.cut(curr_df["MILES"], bins, labels=binLabels))["OCCURENCES"].sum().plot(kind='bar', color='#FF2200')
#bin_df.value_counts(sort=False).plot(kind='bar')
plt.title("Fig 8 - Number of Failure Occurrences by Mile", y=1.1);
plt.xlabel("Miles at Failure (thousands)", fontsize=12);
plt.ylabel("Number of Occurrences", fontsize=12);
plt.gcf()

#bins = py.linspace(0, 300000, numBins)
#bins = math.floor(bins)
#bins
#bin_df.value_counts(sort=False)

#cmpl_df['MILES'].value_counts()
#bin_df.describe()
#cmpl_df["MILES"].describe()

#bins = [900000, 1000000];
#cmpl_df.groupby(pd.cut(cmpl_df['MILES'], bins))["OCCURENCES"].describe()

#curr_df["OCCURENCES"].describe()
#curr_df[(curr_df["OCCURRENCES"] >= 980000) & (curr_df["MILES"] < 1000000)]

# %%
cmpl_df = cmpl_df_new[cmpl_df_new["CMPLID"] > 1347687];

matplotlib.style.use('ggplot')

orange = '#FF6600';
blue = '#6666FF';

plotParams = {'labels':['No','Yes'], 'colors':[blue, orange], 'autopct':'%1.1f%%'}
titleOffset = 1.1;

plt.figure()
#cmpl_df["CRASH"].value_counts().plot.pie(labels=['No','Yes'], colors=[blue, orange], autopct='%1.1f%%');
cmpl_df["CRASH"].value_counts().plot.pie(**plotParams);
plt.title("Defects involving a Crash", y=titleOffset);
plt.axis('equal')
plt.ylabel("");
plt.show();

plt.figure()
((cmpl_df["INJURED"] > 0) | (cmpl_df["DEATHS"] > 0)).value_counts().plot.pie(**plotParams);
plt.title("Defects Involving Injuries or Death", y=titleOffset);
plt.axis('equal')
plt.ylabel("");
plt.show();

crashes_df = cmpl_df[cmpl_df["CRASH"] == 'Y'];

plt.figure()
#((cmpl_df["INJURED"] > 0) | (cmpl_df["DEATHS"] > 0)).value_counts().plot.pie();
((crashes_df["INJURED"] > 0) | (crashes_df["DEATHS"] > 0)).value_counts().plot.pie(**plotParams);
plt.title("Crashes Involving Injuries or Death", y=titleOffset);
plt.axis('equal')
plt.ylabel("");
plt.show();

# %%
cmpl_df = load_data_file('CMPL', encoding='iso-8859-1')
#cmpl_df_new = load_data_file('CMPL_NEW', encoding='iso-8859-1')

print(cmpl_df["CMPLID"].max())
print(cmpl_df_new["CMPLID"].max())
print(cmpl_df_new["CMPLID"].max() - cmpl_df["CMPLID"].max())

cmpl_df_new[cmpl_df_new["CMPLID"] > 1347687]["CMPLID"].describe()

#cmpl_df['OCCURENCES'].describe()

#clean_col = cmpl_df[(cmpl_df["OCCURENCES"] >= -1000) & (cmpl_df["OCCURENCES"] < 20)]["OCCURENCES"]

#plt.figure()
#clean_col.hist(bins=20, color='#FF5500')
#clean_df.plot(kind='scatter', x='MILES', y='OCCURENCES');
#plt.title("Fig 7 - Milage at Failure", y=1.1)
#plt.ylabel('Number of Failures', fontsize=12)
#plt.xlabel('Miles at Failure (thousands)', fontsize=12)
#plt.gcf()

# %% [markdown]
# # Data cleaning for prediction

# %% [markdown]
# ### Load the Complaints dataset

# %%
# Load the complaints dataset.
# Only use a subset of the data (because there is a lot of it)
cmpl_train_df = load_data_file('CMPL', encoding='iso-8859-1').tail(50000);
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (15,22,26,32,33,34,35,36,38,39,40,41,42,43,44,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %% [markdown]
# ### Filter and clean the Complaints dataset

# %%
# Create list of the columns we will use.
key_cols = ['MAKETXT', 'MODELTXT', 'YEARTXT','COMPDESC']
cat_cols = ['DRIVE_TRAIN', 'FUEL_SYS', 'FUEL_TYPE', 'TRANS_TYPE']
bool_cols = ['CRASH', 'FIRE', 'POLICE_RPT_YN', 'ORIG_OWNER_YN', 'ANTI_BRAKES_YN', 'CRUISE_CONT_YN', 'MEDICAL_ATTN', 'VEHICLES_TOWED_YN']
numer_cols = bool_cols + ['INJURED', 'DEATHS', 'MILES', 'OCCURENCES', 'NUM_CYLS', 'VEH_SPEED']
all_cols = key_cols + numer_cols + cat_cols

# Filter out rows with invalid make, model, or year.
# Also filter out any non-vehicles.
clean_train_df = cmpl_train_df[(cmpl_train_df['MAKETXT'] != 'UNKNOWN') &
                   (cmpl_train_df['MODELTXT'] != 'UNKNOWN') &
                   (cmpl_train_df['YEARTXT'] > 1900) &
                   (cmpl_train_df['YEARTXT'] < 2020) &
                   (cmpl_train_df['PROD_TYPE'] == 'V')][all_cols + ['CMPLID']].copy()

# shoulda bought more ram
del cmpl_train_df

# Convert certain columns to a numerical data type.
clean_train_df['NUM_CYLS'] = pd.to_numeric(clean_train_df['NUM_CYLS'], errors='coerce')

# Replace particular "bogus" values with NaN, which get filled later.
clean_train_df['INJURED'] = clean_train_df['INJURED'].replace(99, np.nan).fillna(0)
clean_train_df['DEATHS'] = clean_train_df['DEATHS'].replace(99, np.nan).fillna(0)

# Clamp the values for specific numerical columns.
clean_train_df['NUM_CYLS'] = clean_train_df['NUM_CYLS'].clip(4, 8)
clean_train_df['MILES'] = clean_train_df['MILES'].clip(0, 300000)
clean_train_df['OCCURENCES'] = clean_train_df['OCCURENCES'].clip(1, 10)
clean_train_df['VEH_SPEED'] = clean_train_df['VEH_SPEED'].clip(0, 100)

#Clean values in component descriptions
#Custom split function to pass to apply
def split(comp):
    if type(comp) != str:
        return ''
    return comp.split(':')[0]

#Generalize the names of each component
clean_train_df['COMPDESC'] = clean_train_df['COMPDESC'].apply(split)

# Fix differences between component names in complaints and recalls
clean_train_df['COMPDESC'] = clean_train_df['COMPDESC'].replace('FUEL/PROPULSION SYSTEM','FUEL SYSTEM').replace('AIR BAG','AIR BAGS')
clean_train_df['COMPDESC'] = clean_train_df['COMPDESC'].replace('OTHER','').replace('UNKNOWN OR OTHER','')

# Replace 'Y' and 'N' with 1 and 0 for boolean columns.
# Also convert them to numeric so we can average them.
# This will allow us to get a percentage of 'yes' for each vehicle type.
for column in bool_cols:
    clean_train_df[column] = clean_train_df[column].replace('Y', 1).replace('N', 0)
    clean_train_df[column] = pd.to_numeric(clean_train_df[column])

# Print out part of the resulting semi-clean data set
clean_train_df[all_cols].head(10)
# Out:
#           MAKETXT  MODELTXT  YEARTXT                   COMPDESC  CRASH  FIRE  \
# 1297262     BUICK  LACROSSE   2006.0                 SEAT BELTS      0     0
# 1297263     BUICK  LACROSSE   2006.0                   AIR BAGS      0     0
# 1297264   PONTIAC        G5   2007.0          EXTERIOR LIGHTING      0     0
# 1297265   PONTIAC        G5   2007.0          ELECTRICAL SYSTEM      0     0
# 1297266   PONTIAC        G5   2007.0                     ENGINE      0     0
# 1297267      FIAT       500   2012.0                     ENGINE      0     0
# 1297268      FIAT       500   2012.0                POWER TRAIN      0     0
# 1297269      FIAT       500   2012.0      VEHICLE SPEED CONTROL      0     0
# 1297270     HONDA      CR-V   2007.0                   AIR BAGS      0     0
# 1297271  KENWORTH      T680   2016.0  SERVICE BRAKES, HYDRAULIC      0     0
#
#          POLICE_RPT_YN  ORIG_OWNER_YN  ANTI_BRAKES_YN  CRUISE_CONT_YN  \
# 1297262              0            0.0             1.0             1.0
# 1297263              0            0.0             1.0             1.0
# 1297264              0            0.0             0.0             0.0
# 1297265              0            0.0             0.0             0.0
# 1297266              0            0.0             0.0             0.0
# 1297267              0            0.0             0.0             0.0
# 1297268              0            0.0             0.0             0.0
# 1297269              0            0.0             0.0             0.0
# 1297270              0            0.0             0.0             0.0
# 1297271              0            0.0             0.0             0.0
#
#            ...      INJURED  DEATHS    MILES  OCCURENCES  NUM_CYLS  VEH_SPEED  \
# 1297262    ...          0.0     0.0  63530.0         1.0       6.0       40.0
# 1297263    ...          0.0     0.0  63530.0         1.0       6.0       40.0
# 1297264    ...          0.0     0.0  79800.0         NaN       NaN       70.0
# 1297265    ...          0.0     0.0  79800.0         NaN       NaN       70.0
# 1297266    ...          0.0     0.0  79800.0         NaN       NaN       70.0
# 1297267    ...          0.0     0.0  38000.0         NaN       NaN        NaN
# 1297268    ...          0.0     0.0  38000.0         NaN       NaN        NaN
# 1297269    ...          0.0     0.0  38000.0         NaN       NaN        NaN
# 1297270    ...          0.0     0.0      NaN         1.0       4.0        NaN
# 1297271    ...          0.0     0.0  20000.0         NaN       NaN       65.0
#
#          DRIVE_TRAIN  FUEL_SYS FUEL_TYPE TRANS_TYPE
# 1297262          FWD        FI        GS       AUTO
# 1297263          FWD        FI        GS       AUTO
# 1297264          NaN       NaN       NaN        NaN
# 1297265          NaN       NaN       NaN        NaN
# 1297266          NaN       NaN       NaN        NaN
# 1297267          NaN       NaN       NaN        NaN
# 1297268          NaN       NaN       NaN        NaN
# 1297269          NaN       NaN       NaN        NaN
# 1297270          AWD        FI        GS        NaN
# 1297271          NaN       NaN       NaN        NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# ### Group complaints by make/model/year and perform aggregate functions on the column values
#
# Warning: this step takes a few minutes to perform all the aggregate functions

# %%
# Aggregate function which Returns the mode of a series.
# If there is no valid mode, but there are any amount of
# non-null values, then the first non-null value is returned.
# Otherwise, if all values are NaN, then NaN is returned
def aggMode(x):
    column_mode = x.mode()
    
    # If there is a valid mode, return it
    if column_mode.count() > 0:
        return column_mode[0]
   
    # if there are any non-null values, return one of them
    first_valid = x.first_valid_index()
    if first_valid != None:
        return x[first_valid]
    
    return np.nan
#}

# %%
# Group the dataset by the key columns (make/model/year/component)
grouped = clean_train_df.groupby(key_cols)

# Perform aggregate functions on the columns for each vehicle type.
# Aggregate with the mode for categorical columns
# Aggregate with the mean for numerical columns
grouped_df = pd.DataFrame()
for col in cat_cols:
    grouped_df[col] = grouped[col].agg(aggMode)
for col in numer_cols:
    grouped_df[col] = grouped[col].mean()

# Add in a column for the number of complaints for each vehicle-component.
grouped_df['COMPLAINTS'] = grouped.size()
numer_cols.append('COMPLAINTS');
all_cols.append('COMPLAINTS');

print('done')
# Out:
# done

# %% [markdown]
# ### Replace missing values with the mean or mode for that column over the entire dataset

# %%
# Replace NaN with mode for categorical columns
for col in cat_cols:
    grouped_df[col] = grouped_df[col].fillna(grouped_df[col].mode()[0])

# Replace NaN with mean for numerical columns
for col in numer_cols:
    grouped_df[col] = grouped_df[col].fillna(grouped_df[col].mean())

print('done')
# Out:
# done

# %%
# Print out the grouped dataset.
grouped_df
# Out:
#                                                          DRIVE_TRAIN FUEL_SYS  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                       FWD       FI
#                             ELECTRICAL SYSTEM                    FWD       FI
#                     1998.0  AIR BAGS                             FWD       FI
#                     2001.0  POWER TRAIN                          FWD       FI
#                     2003.0  POWER TRAIN                          FWD       FI
#         ILX         2013.0  AIR BAGS                             FWD       FI
#                     2014.0  AIR BAGS                             FWD       FI
#                     2015.0  AIR BAGS                             FWD       FI
#                     2016.0  AIR BAGS                             FWD       FI
#                             ELECTRICAL SYSTEM                    FWD       FI
#                             POWER TRAIN                          FWD       FI
#                     2017.0  POWER TRAIN                          FWD       FI
#         INTEGRA     1994.0  VISIBILITY/WIPER                     FWD       FI
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC            FWD       FI
#                     1994.0  ELECTRICAL SYSTEM                    FWD       FI
#                             SEATS                                FWD       FI
#         MDX         2001.0  AIR BAGS                             FWD       FI
#                             ELECTRONIC STABILITY CONTROL         FWD       FI
#                             ENGINE                               FWD       FI
#                             FUEL SYSTEM                          FWD       FI
#                             POWER TRAIN                          FWD       FI
#                             SUSPENSION                           FWD       FI
#                             VEHICLE SPEED CONTROL                FWD       FI
#                     2002.0  AIR BAGS                             FWD       FI
#                             ENGINE                               FWD       FI
#                             POWER TRAIN                          FWD       FI
#                     2003.0                                       FWD       FI
#                             AIR BAGS                             FWD       FI
#                             ELECTRICAL SYSTEM                    FWD       FI
#                             ENGINE                               FWD       FI
# ...                                                              ...      ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM                    FWD       FI
#                     2005.0  ELECTRICAL SYSTEM                    FWD       FI
#                     2006.0  EXTERIOR LIGHTING                    FWD       FI
#         FZ-09       2015.0  POWER TRAIN                          FWD       FI
#         FZ09        2014.0  ELECTRICAL SYSTEM                    FWD       FI
#                             ENGINE                               FWD       FI
#                             POWER TRAIN                          FWD       FI
#         ROAD STAR   2007.0  FUEL SYSTEM                          FWD       FI
#                             POWER TRAIN                          FWD       FI
#         ROADLINER   2006.0  ENGINE                               FWD       FI
#                             POWER TRAIN                          FWD       FI
#         STRATOLINER 2006.0  POWER TRAIN                          FWD       FI
#         XSR900      2016.0  ELECTRICAL SYSTEM                    FWD       FI
#         XT1200Z     2013.0  WHEELS                               FWD       FI
#         XT250       2015.0  ENGINE                               FWD       FI
#                             FUEL SYSTEM                          FWD       FI
#         XTZ12       2013.0  WHEELS                               FWD       FI
#         XV1900      2008.0  FUEL SYSTEM                          FWD       FI
#         XVS11       2003.0  POWER TRAIN                          FWD       FI
#         XVS1100     2005.0                                       FWD       FI
#         XVS65       2003.0  POWER TRAIN                          FWD       FI
#                     2004.0  POWER TRAIN                          FWD       FI
#         XVS950      2014.0  ENGINE                               FWD       FI
#         YZF-R3      2015.0  ENGINE                               FWD       FI
#                             STEERING                             FWD       FI
#                             SUSPENSION                           FWD       FI
#         YZF600      2003.0  POWER TRAIN                          FWD       FI
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                    FWD       FI
#                             EXTERIOR LIGHTING                    FWD       FI
#         ZERO X      2012.0  FUEL SYSTEM                          FWD       FI
#
#                                                          FUEL_TYPE TRANS_TYPE  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                      GS       AUTO
#                             ELECTRICAL SYSTEM                   GS       AUTO
#                     1998.0  AIR BAGS                            GS       AUTO
#                     2001.0  POWER TRAIN                         GS       AUTO
#                     2003.0  POWER TRAIN                         GS       AUTO
#         ILX         2013.0  AIR BAGS                            GS       AUTO
#                     2014.0  AIR BAGS                            GS       AUTO
#                     2015.0  AIR BAGS                            GS       AUTO
#                     2016.0  AIR BAGS                            GS       AUTO
#                             ELECTRICAL SYSTEM                   GS       AUTO
#                             POWER TRAIN                         GS       AUTO
#                     2017.0  POWER TRAIN                         GS       AUTO
#         INTEGRA     1994.0  VISIBILITY/WIPER                    GS       AUTO
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC           GS       AUTO
#                     1994.0  ELECTRICAL SYSTEM                   GS       AUTO
#                             SEATS                               GS       AUTO
#         MDX         2001.0  AIR BAGS                            GS       AUTO
#                             ELECTRONIC STABILITY CONTROL        GS       AUTO
#                             ENGINE                              GS       AUTO
#                             FUEL SYSTEM                         GS       AUTO
#                             POWER TRAIN                         GS       AUTO
#                             SUSPENSION                          GS       AUTO
#                             VEHICLE SPEED CONTROL               GS       AUTO
#                     2002.0  AIR BAGS                            GS       AUTO
#                             ENGINE                              GS       AUTO
#                             POWER TRAIN                         GS       AUTO
#                     2003.0                                      GS       AUTO
#                             AIR BAGS                            GS       AUTO
#                             ELECTRICAL SYSTEM                   GS       AUTO
#                             ENGINE                              GS       AUTO
# ...                                                            ...        ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM                   GS        MAN
#                     2005.0  ELECTRICAL SYSTEM                   GS       AUTO
#                     2006.0  EXTERIOR LIGHTING                   GS       AUTO
#         FZ-09       2015.0  POWER TRAIN                         GS       AUTO
#         FZ09        2014.0  ELECTRICAL SYSTEM                   GS       AUTO
#                             ENGINE                              GS       AUTO
#                             POWER TRAIN                         GS       AUTO
#         ROAD STAR   2007.0  FUEL SYSTEM                         GS       AUTO
#                             POWER TRAIN                         GS       AUTO
#         ROADLINER   2006.0  ENGINE                              GS       AUTO
#                             POWER TRAIN                         GS       AUTO
#         STRATOLINER 2006.0  POWER TRAIN                         GS       AUTO
#         XSR900      2016.0  ELECTRICAL SYSTEM                   GS       AUTO
#         XT1200Z     2013.0  WHEELS                              GS       AUTO
#         XT250       2015.0  ENGINE                              GS       AUTO
#                             FUEL SYSTEM                         GS       AUTO
#         XTZ12       2013.0  WHEELS                              GS       AUTO
#         XV1900      2008.0  FUEL SYSTEM                         GS       AUTO
#         XVS11       2003.0  POWER TRAIN                         GS       AUTO
#         XVS1100     2005.0                                      GS       AUTO
#         XVS65       2003.0  POWER TRAIN                         GS       AUTO
#                     2004.0  POWER TRAIN                         GS       AUTO
#         XVS950      2014.0  ENGINE                              GS       AUTO
#         YZF-R3      2015.0  ENGINE                              GS       AUTO
#                             STEERING                            GS       AUTO
#                             SUSPENSION                          GS       AUTO
#         YZF600      2003.0  POWER TRAIN                         GS       AUTO
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                   GS       AUTO
#                             EXTERIOR LIGHTING                   GS       AUTO
#         ZERO X      2012.0  FUEL SYSTEM                         GS       AUTO
#
#                                                              CRASH  FIRE  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                0.000000   0.0
#                             ELECTRICAL SYSTEM             0.000000   0.0
#                     1998.0  AIR BAGS                      0.000000   0.0
#                     2001.0  POWER TRAIN                   0.000000   0.0
#                     2003.0  POWER TRAIN                   0.000000   0.0
#         ILX         2013.0  AIR BAGS                      0.000000   0.0
#                     2014.0  AIR BAGS                      0.000000   0.0
#                     2015.0  AIR BAGS                      0.000000   0.0
#                     2016.0  AIR BAGS                      0.333333   0.0
#                             ELECTRICAL SYSTEM             0.000000   0.0
#                             POWER TRAIN                   0.000000   0.0
#                     2017.0  POWER TRAIN                   0.000000   0.0
#         INTEGRA     1994.0  VISIBILITY/WIPER              0.000000   0.0
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC     1.000000   0.0
#                     1994.0  ELECTRICAL SYSTEM             0.000000   1.0
#                             SEATS                         0.000000   1.0
#         MDX         2001.0  AIR BAGS                      0.000000   0.0
#                             ELECTRONIC STABILITY CONTROL  0.000000   0.0
#                             ENGINE                        0.000000   0.0
#                             FUEL SYSTEM                   0.000000   0.0
#                             POWER TRAIN                   0.000000   0.0
#                             SUSPENSION                    0.000000   0.0
#                             VEHICLE SPEED CONTROL         0.000000   0.0
#                     2002.0  AIR BAGS                      0.000000   0.0
#                             ENGINE                        0.000000   0.0
#                             POWER TRAIN                   0.250000   0.0
#                     2003.0                                0.000000   0.0
#                             AIR BAGS                      0.000000   0.0
#                             ELECTRICAL SYSTEM             0.000000   0.0
#                             ENGINE                        0.000000   0.0
# ...                                                            ...   ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM             0.000000   0.0
#                     2005.0  ELECTRICAL SYSTEM             0.000000   0.0
#                     2006.0  EXTERIOR LIGHTING             0.000000   0.0
#         FZ-09       2015.0  POWER TRAIN                   0.000000   0.0
#         FZ09        2014.0  ELECTRICAL SYSTEM             0.000000   0.0
#                             ENGINE                        0.000000   0.0
#                             POWER TRAIN                   0.000000   0.0
#         ROAD STAR   2007.0  FUEL SYSTEM                   0.000000   0.0
#                             POWER TRAIN                   0.000000   0.0
#         ROADLINER   2006.0  ENGINE                        0.000000   0.0
#                             POWER TRAIN                   0.000000   0.0
#         STRATOLINER 2006.0  POWER TRAIN                   0.000000   0.0
#         XSR900      2016.0  ELECTRICAL SYSTEM             0.000000   0.0
#         XT1200Z     2013.0  WHEELS                        0.000000   0.0
#         XT250       2015.0  ENGINE                        0.000000   0.0
#                             FUEL SYSTEM                   0.000000   0.0
#         XTZ12       2013.0  WHEELS                        0.000000   0.0
#         XV1900      2008.0  FUEL SYSTEM                   0.000000   0.0
#         XVS11       2003.0  POWER TRAIN                   0.000000   0.0
#         XVS1100     2005.0                                0.000000   0.0
#         XVS65       2003.0  POWER TRAIN                   0.000000   0.0
#                     2004.0  POWER TRAIN                   0.000000   0.0
#         XVS950      2014.0  ENGINE                        0.000000   0.0
#         YZF-R3      2015.0  ENGINE                        0.000000   0.0
#                             STEERING                      0.000000   0.0
#                             SUSPENSION                    0.000000   0.0
#         YZF600      2003.0  POWER TRAIN                   0.000000   0.0
# ZERO    FX          2016.0  ELECTRICAL SYSTEM             0.000000   0.0
#                             EXTERIOR LIGHTING             0.000000   0.0
#         ZERO X      2012.0  FUEL SYSTEM                   0.000000   0.0
#
#                                                           POLICE_RPT_YN  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                          0.0
#                             ELECTRICAL SYSTEM                       0.0
#                     1998.0  AIR BAGS                                0.0
#                     2001.0  POWER TRAIN                             0.0
#                     2003.0  POWER TRAIN                             0.0
#         ILX         2013.0  AIR BAGS                                0.0
#                     2014.0  AIR BAGS                                0.0
#                     2015.0  AIR BAGS                                0.0
#                     2016.0  AIR BAGS                                0.0
#                             ELECTRICAL SYSTEM                       0.0
#                             POWER TRAIN                             0.0
#                     2017.0  POWER TRAIN                             0.0
#         INTEGRA     1994.0  VISIBILITY/WIPER                        0.0
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC               1.0
#                     1994.0  ELECTRICAL SYSTEM                       0.0
#                             SEATS                                   0.0
#         MDX         2001.0  AIR BAGS                                0.0
#                             ELECTRONIC STABILITY CONTROL            0.0
#                             ENGINE                                  0.0
#                             FUEL SYSTEM                             0.0
#                             POWER TRAIN                             0.0
#                             SUSPENSION                              0.0
#                             VEHICLE SPEED CONTROL                   0.0
#                     2002.0  AIR BAGS                                0.0
#                             ENGINE                                  0.0
#                             POWER TRAIN                             0.0
#                     2003.0                                          0.0
#                             AIR BAGS                                0.0
#                             ELECTRICAL SYSTEM                       0.0
#                             ENGINE                                  0.0
# ...                                                                 ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM                       0.0
#                     2005.0  ELECTRICAL SYSTEM                       0.0
#                     2006.0  EXTERIOR LIGHTING                       0.0
#         FZ-09       2015.0  POWER TRAIN                             0.0
#         FZ09        2014.0  ELECTRICAL SYSTEM                       0.0
#                             ENGINE                                  0.0
#                             POWER TRAIN                             0.0
#         ROAD STAR   2007.0  FUEL SYSTEM                             0.0
#                             POWER TRAIN                             0.0
#         ROADLINER   2006.0  ENGINE                                  0.0
#                             POWER TRAIN                             0.0
#         STRATOLINER 2006.0  POWER TRAIN                             0.0
#         XSR900      2016.0  ELECTRICAL SYSTEM                       0.0
#         XT1200Z     2013.0  WHEELS                                  0.0
#         XT250       2015.0  ENGINE                                  0.0
#                             FUEL SYSTEM                             0.0
#         XTZ12       2013.0  WHEELS                                  0.0
#         XV1900      2008.0  FUEL SYSTEM                             0.0
#         XVS11       2003.0  POWER TRAIN                             0.0
#         XVS1100     2005.0                                          0.0
#         XVS65       2003.0  POWER TRAIN                             0.0
#                     2004.0  POWER TRAIN                             0.0
#         XVS950      2014.0  ENGINE                                  0.0
#         YZF-R3      2015.0  ENGINE                                  0.0
#                             STEERING                                0.0
#                             SUSPENSION                              0.0
#         YZF600      2003.0  POWER TRAIN                             0.0
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                       0.0
#                             EXTERIOR LIGHTING                       0.0
#         ZERO X      2012.0  FUEL SYSTEM                             0.0
#
#                                                           ORIG_OWNER_YN  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                        0.000
#                             ELECTRICAL SYSTEM                     0.000
#                     1998.0  AIR BAGS                              0.000
#                     2001.0  POWER TRAIN                           0.000
#                     2003.0  POWER TRAIN                           0.000
#         ILX         2013.0  AIR BAGS                              0.000
#                     2014.0  AIR BAGS                              0.125
#                     2015.0  AIR BAGS                              0.250
#                     2016.0  AIR BAGS                              0.000
#                             ELECTRICAL SYSTEM                     0.000
#                             POWER TRAIN                           0.000
#                     2017.0  POWER TRAIN                           0.000
#         INTEGRA     1994.0  VISIBILITY/WIPER                      0.000
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC             0.000
#                     1994.0  ELECTRICAL SYSTEM                     0.000
#                             SEATS                                 0.000
#         MDX         2001.0  AIR BAGS                              0.000
#                             ELECTRONIC STABILITY CONTROL          0.000
#                             ENGINE                                0.000
#                             FUEL SYSTEM                           0.000
#                             POWER TRAIN                           0.000
#                             SUSPENSION                            0.000
#                             VEHICLE SPEED CONTROL                 0.000
#                     2002.0  AIR BAGS                              0.000
#                             ENGINE                                0.000
#                             POWER TRAIN                           0.000
#                     2003.0                                        0.000
#                             AIR BAGS                              0.000
#                             ELECTRICAL SYSTEM                     0.000
#                             ENGINE                                0.000
# ...                                                                 ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM                     1.000
#                     2005.0  ELECTRICAL SYSTEM                     0.000
#                     2006.0  EXTERIOR LIGHTING                     0.000
#         FZ-09       2015.0  POWER TRAIN                           0.000
#         FZ09        2014.0  ELECTRICAL SYSTEM                     0.000
#                             ENGINE                                0.000
#                             POWER TRAIN                           0.000
#         ROAD STAR   2007.0  FUEL SYSTEM                           0.000
#                             POWER TRAIN                           0.000
#         ROADLINER   2006.0  ENGINE                                0.000
#                             POWER TRAIN                           0.000
#         STRATOLINER 2006.0  POWER TRAIN                           0.000
#         XSR900      2016.0  ELECTRICAL SYSTEM                     0.000
#         XT1200Z     2013.0  WHEELS                                0.000
#         XT250       2015.0  ENGINE                                0.000
#                             FUEL SYSTEM                           0.000
#         XTZ12       2013.0  WHEELS                                0.000
#         XV1900      2008.0  FUEL SYSTEM                           0.000
#         XVS11       2003.0  POWER TRAIN                           0.000
#         XVS1100     2005.0                                        0.000
#         XVS65       2003.0  POWER TRAIN                           0.000
#                     2004.0  POWER TRAIN                           0.000
#         XVS950      2014.0  ENGINE                                0.000
#         YZF-R3      2015.0  ENGINE                                0.000
#                             STEERING                              0.000
#                             SUSPENSION                            0.000
#         YZF600      2003.0  POWER TRAIN                           0.000
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                     0.000
#                             EXTERIOR LIGHTING                     0.000
#         ZERO X      2012.0  FUEL SYSTEM                           0.000
#
#                                                           ANTI_BRAKES_YN  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                         0.000
#                             ELECTRICAL SYSTEM                      0.000
#                     1998.0  AIR BAGS                               0.000
#                     2001.0  POWER TRAIN                            0.000
#                     2003.0  POWER TRAIN                            0.000
#         ILX         2013.0  AIR BAGS                               0.000
#                     2014.0  AIR BAGS                               0.125
#                     2015.0  AIR BAGS                               0.000
#                     2016.0  AIR BAGS                               0.000
#                             ELECTRICAL SYSTEM                      0.000
#                             POWER TRAIN                            0.000
#                     2017.0  POWER TRAIN                            0.000
#         INTEGRA     1994.0  VISIBILITY/WIPER                       0.000
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC              0.000
#                     1994.0  ELECTRICAL SYSTEM                      0.000
#                             SEATS                                  0.000
#         MDX         2001.0  AIR BAGS                               0.000
#                             ELECTRONIC STABILITY CONTROL           0.000
#                             ENGINE                                 0.000
#                             FUEL SYSTEM                            0.000
#                             POWER TRAIN                            0.000
#                             SUSPENSION                             0.000
#                             VEHICLE SPEED CONTROL                  0.000
#                     2002.0  AIR BAGS                               0.000
#                             ENGINE                                 0.000
#                             POWER TRAIN                            0.000
#                     2003.0                                         0.000
#                             AIR BAGS                               0.000
#                             ELECTRICAL SYSTEM                      0.000
#                             ENGINE                                 0.000
# ...                                                                  ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM                      0.000
#                     2005.0  ELECTRICAL SYSTEM                      0.000
#                     2006.0  EXTERIOR LIGHTING                      0.000
#         FZ-09       2015.0  POWER TRAIN                            0.000
#         FZ09        2014.0  ELECTRICAL SYSTEM                      0.000
#                             ENGINE                                 0.000
#                             POWER TRAIN                            0.000
#         ROAD STAR   2007.0  FUEL SYSTEM                            0.000
#                             POWER TRAIN                            0.000
#         ROADLINER   2006.0  ENGINE                                 0.000
#                             POWER TRAIN                            0.000
#         STRATOLINER 2006.0  POWER TRAIN                            0.000
#         XSR900      2016.0  ELECTRICAL SYSTEM                      0.000
#         XT1200Z     2013.0  WHEELS                                 0.000
#         XT250       2015.0  ENGINE                                 0.000
#                             FUEL SYSTEM                            0.000
#         XTZ12       2013.0  WHEELS                                 0.000
#         XV1900      2008.0  FUEL SYSTEM                            0.000
#         XVS11       2003.0  POWER TRAIN                            0.000
#         XVS1100     2005.0                                         0.000
#         XVS65       2003.0  POWER TRAIN                            0.000
#                     2004.0  POWER TRAIN                            0.000
#         XVS950      2014.0  ENGINE                                 0.000
#         YZF-R3      2015.0  ENGINE                                 0.000
#                             STEERING                               0.000
#                             SUSPENSION                             0.000
#         YZF600      2003.0  POWER TRAIN                            0.000
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                      0.000
#                             EXTERIOR LIGHTING                      0.000
#         ZERO X      2012.0  FUEL SYSTEM                            0.000
#
#                                                           CRUISE_CONT_YN  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                         0.000
#                             ELECTRICAL SYSTEM                      0.000
#                     1998.0  AIR BAGS                               0.000
#                     2001.0  POWER TRAIN                            0.000
#                     2003.0  POWER TRAIN                            0.000
#         ILX         2013.0  AIR BAGS                               0.000
#                     2014.0  AIR BAGS                               0.125
#                     2015.0  AIR BAGS                               0.000
#                     2016.0  AIR BAGS                               0.000
#                             ELECTRICAL SYSTEM                      0.000
#                             POWER TRAIN                            0.000
#                     2017.0  POWER TRAIN                            0.000
#         INTEGRA     1994.0  VISIBILITY/WIPER                       0.000
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC              0.000
#                     1994.0  ELECTRICAL SYSTEM                      0.000
#                             SEATS                                  0.000
#         MDX         2001.0  AIR BAGS                               0.000
#                             ELECTRONIC STABILITY CONTROL           0.000
#                             ENGINE                                 0.000
#                             FUEL SYSTEM                            0.000
#                             POWER TRAIN                            0.000
#                             SUSPENSION                             0.000
#                             VEHICLE SPEED CONTROL                  0.000
#                     2002.0  AIR BAGS                               0.000
#                             ENGINE                                 0.000
#                             POWER TRAIN                            0.000
#                     2003.0                                         0.000
#                             AIR BAGS                               0.000
#                             ELECTRICAL SYSTEM                      0.000
#                             ENGINE                                 0.000
# ...                                                                  ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM                      0.000
#                     2005.0  ELECTRICAL SYSTEM                      0.000
#                     2006.0  EXTERIOR LIGHTING                      0.000
#         FZ-09       2015.0  POWER TRAIN                            0.000
#         FZ09        2014.0  ELECTRICAL SYSTEM                      0.000
#                             ENGINE                                 0.000
#                             POWER TRAIN                            0.000
#         ROAD STAR   2007.0  FUEL SYSTEM                            0.000
#                             POWER TRAIN                            0.000
#         ROADLINER   2006.0  ENGINE                                 0.000
#                             POWER TRAIN                            0.000
#         STRATOLINER 2006.0  POWER TRAIN                            0.000
#         XSR900      2016.0  ELECTRICAL SYSTEM                      0.000
#         XT1200Z     2013.0  WHEELS                                 0.000
#         XT250       2015.0  ENGINE                                 0.000
#                             FUEL SYSTEM                            0.000
#         XTZ12       2013.0  WHEELS                                 0.000
#         XV1900      2008.0  FUEL SYSTEM                            0.000
#         XVS11       2003.0  POWER TRAIN                            0.000
#         XVS1100     2005.0                                         0.000
#         XVS65       2003.0  POWER TRAIN                            0.000
#                     2004.0  POWER TRAIN                            0.000
#         XVS950      2014.0  ENGINE                                 0.000
#         YZF-R3      2015.0  ENGINE                                 0.000
#                             STEERING                               0.000
#                             SUSPENSION                             0.000
#         YZF600      2003.0  POWER TRAIN                            0.000
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                      0.000
#                             EXTERIOR LIGHTING                      0.000
#         ZERO X      2012.0  FUEL SYSTEM                            0.000
#
#                                                           MEDICAL_ATTN  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                    0.000000
#                             ELECTRICAL SYSTEM                 0.000000
#                     1998.0  AIR BAGS                          0.000000
#                     2001.0  POWER TRAIN                       0.000000
#                     2003.0  POWER TRAIN                       0.000000
#         ILX         2013.0  AIR BAGS                          0.000000
#                     2014.0  AIR BAGS                          0.000000
#                     2015.0  AIR BAGS                          0.000000
#                     2016.0  AIR BAGS                          0.333333
#                             ELECTRICAL SYSTEM                 0.000000
#                             POWER TRAIN                       0.000000
#                     2017.0  POWER TRAIN                       0.000000
#         INTEGRA     1994.0  VISIBILITY/WIPER                  0.000000
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC         0.000000
#                     1994.0  ELECTRICAL SYSTEM                 0.000000
#                             SEATS                             0.000000
#         MDX         2001.0  AIR BAGS                          0.000000
#                             ELECTRONIC STABILITY CONTROL      0.000000
#                             ENGINE                            0.000000
#                             FUEL SYSTEM                       0.000000
#                             POWER TRAIN                       0.000000
#                             SUSPENSION                        0.000000
#                             VEHICLE SPEED CONTROL             0.000000
#                     2002.0  AIR BAGS                          0.000000
#                             ENGINE                            0.000000
#                             POWER TRAIN                       0.000000
#                     2003.0                                    0.000000
#                             AIR BAGS                          0.000000
#                             ELECTRICAL SYSTEM                 0.000000
#                             ENGINE                            0.000000
# ...                                                                ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM                 0.000000
#                     2005.0  ELECTRICAL SYSTEM                 0.000000
#                     2006.0  EXTERIOR LIGHTING                 0.000000
#         FZ-09       2015.0  POWER TRAIN                       0.000000
#         FZ09        2014.0  ELECTRICAL SYSTEM                 0.000000
#                             ENGINE                            0.000000
#                             POWER TRAIN                       0.000000
#         ROAD STAR   2007.0  FUEL SYSTEM                       0.000000
#                             POWER TRAIN                       0.000000
#         ROADLINER   2006.0  ENGINE                            0.000000
#                             POWER TRAIN                       0.000000
#         STRATOLINER 2006.0  POWER TRAIN                       0.000000
#         XSR900      2016.0  ELECTRICAL SYSTEM                 0.000000
#         XT1200Z     2013.0  WHEELS                            0.000000
#         XT250       2015.0  ENGINE                            0.000000
#                             FUEL SYSTEM                       0.000000
#         XTZ12       2013.0  WHEELS                            0.000000
#         XV1900      2008.0  FUEL SYSTEM                       0.000000
#         XVS11       2003.0  POWER TRAIN                       0.000000
#         XVS1100     2005.0                                    0.000000
#         XVS65       2003.0  POWER TRAIN                       0.000000
#                     2004.0  POWER TRAIN                       0.000000
#         XVS950      2014.0  ENGINE                            0.000000
#         YZF-R3      2015.0  ENGINE                            0.000000
#                             STEERING                          0.000000
#                             SUSPENSION                        0.000000
#         YZF600      2003.0  POWER TRAIN                       0.000000
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                 0.000000
#                             EXTERIOR LIGHTING                 0.000000
#         ZERO X      2012.0  FUEL SYSTEM                       0.000000
#
#                                                           VEHICLES_TOWED_YN  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                             0.00
#                             ELECTRICAL SYSTEM                          0.00
#                     1998.0  AIR BAGS                                   0.00
#                     2001.0  POWER TRAIN                                0.00
#                     2003.0  POWER TRAIN                                0.00
#         ILX         2013.0  AIR BAGS                                   0.00
#                     2014.0  AIR BAGS                                   0.00
#                     2015.0  AIR BAGS                                   0.00
#                     2016.0  AIR BAGS                                   0.00
#                             ELECTRICAL SYSTEM                          0.00
#                             POWER TRAIN                                0.00
#                     2017.0  POWER TRAIN                                0.00
#         INTEGRA     1994.0  VISIBILITY/WIPER                           0.00
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC                  0.00
#                     1994.0  ELECTRICAL SYSTEM                          0.00
#                             SEATS                                      0.00
#         MDX         2001.0  AIR BAGS                                   0.00
#                             ELECTRONIC STABILITY CONTROL               0.00
#                             ENGINE                                     0.00
#                             FUEL SYSTEM                                0.00
#                             POWER TRAIN                                0.00
#                             SUSPENSION                                 0.00
#                             VEHICLE SPEED CONTROL                      0.00
#                     2002.0  AIR BAGS                                   0.00
#                             ENGINE                                     0.00
#                             POWER TRAIN                                0.00
#                     2003.0                                             0.00
#                             AIR BAGS                                   0.25
#                             ELECTRICAL SYSTEM                          0.00
#                             ENGINE                                     0.00
# ...                                                                     ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM                          0.00
#                     2005.0  ELECTRICAL SYSTEM                          0.00
#                     2006.0  EXTERIOR LIGHTING                          0.00
#         FZ-09       2015.0  POWER TRAIN                                0.00
#         FZ09        2014.0  ELECTRICAL SYSTEM                          0.00
#                             ENGINE                                     0.00
#                             POWER TRAIN                                0.00
#         ROAD STAR   2007.0  FUEL SYSTEM                                0.00
#                             POWER TRAIN                                0.00
#         ROADLINER   2006.0  ENGINE                                     0.00
#                             POWER TRAIN                                0.00
#         STRATOLINER 2006.0  POWER TRAIN                                0.00
#         XSR900      2016.0  ELECTRICAL SYSTEM                          0.00
#         XT1200Z     2013.0  WHEELS                                     0.00
#         XT250       2015.0  ENGINE                                     0.00
#                             FUEL SYSTEM                                0.00
#         XTZ12       2013.0  WHEELS                                     0.00
#         XV1900      2008.0  FUEL SYSTEM                                0.00
#         XVS11       2003.0  POWER TRAIN                                0.00
#         XVS1100     2005.0                                             0.00
#         XVS65       2003.0  POWER TRAIN                                0.00
#                     2004.0  POWER TRAIN                                0.00
#         XVS950      2014.0  ENGINE                                     1.00
#         YZF-R3      2015.0  ENGINE                                     0.00
#                             STEERING                                   0.00
#                             SUSPENSION                                 0.00
#         YZF600      2003.0  POWER TRAIN                                0.00
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                          0.00
#                             EXTERIOR LIGHTING                          0.00
#         ZERO X      2012.0  FUEL SYSTEM                                0.00
#
#                                                            INJURED  DEATHS  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                0.000000     0.0
#                             ELECTRICAL SYSTEM             0.000000     0.0
#                     1998.0  AIR BAGS                      0.000000     0.0
#                     2001.0  POWER TRAIN                   0.000000     0.0
#                     2003.0  POWER TRAIN                   0.000000     0.0
#         ILX         2013.0  AIR BAGS                      0.000000     0.0
#                     2014.0  AIR BAGS                      0.000000     0.0
#                     2015.0  AIR BAGS                      0.000000     0.0
#                     2016.0  AIR BAGS                      0.666667     0.0
#                             ELECTRICAL SYSTEM             0.000000     0.0
#                             POWER TRAIN                   0.000000     0.0
#                     2017.0  POWER TRAIN                   0.000000     0.0
#         INTEGRA     1994.0  VISIBILITY/WIPER              0.000000     0.0
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC     0.000000     0.0
#                     1994.0  ELECTRICAL SYSTEM             0.000000     0.0
#                             SEATS                         0.000000     0.0
#         MDX         2001.0  AIR BAGS                      0.000000     0.0
#                             ELECTRONIC STABILITY CONTROL  0.000000     0.0
#                             ENGINE                        0.000000     0.0
#                             FUEL SYSTEM                   0.000000     0.0
#                             POWER TRAIN                   0.000000     0.0
#                             SUSPENSION                    0.000000     0.0
#                             VEHICLE SPEED CONTROL         0.000000     0.0
#                     2002.0  AIR BAGS                      0.000000     0.0
#                             ENGINE                        0.000000     0.0
#                             POWER TRAIN                   0.000000     0.0
#                     2003.0                                0.000000     0.0
#                             AIR BAGS                      0.000000     0.0
#                             ELECTRICAL SYSTEM             0.000000     0.0
#                             ENGINE                        0.000000     0.0
# ...                                                            ...     ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM             0.000000     0.0
#                     2005.0  ELECTRICAL SYSTEM             0.000000     0.0
#                     2006.0  EXTERIOR LIGHTING             0.000000     0.0
#         FZ-09       2015.0  POWER TRAIN                   0.000000     0.0
#         FZ09        2014.0  ELECTRICAL SYSTEM             0.000000     0.0
#                             ENGINE                        0.000000     0.0
#                             POWER TRAIN                   0.000000     0.0
#         ROAD STAR   2007.0  FUEL SYSTEM                   0.000000     0.0
#                             POWER TRAIN                   0.000000     0.0
#         ROADLINER   2006.0  ENGINE                        0.000000     0.0
#                             POWER TRAIN                   0.000000     0.0
#         STRATOLINER 2006.0  POWER TRAIN                   0.000000     0.0
#         XSR900      2016.0  ELECTRICAL SYSTEM             0.000000     0.0
#         XT1200Z     2013.0  WHEELS                        0.000000     0.0
#         XT250       2015.0  ENGINE                        0.000000     0.0
#                             FUEL SYSTEM                   0.000000     0.0
#         XTZ12       2013.0  WHEELS                        0.000000     0.0
#         XV1900      2008.0  FUEL SYSTEM                   0.000000     0.0
#         XVS11       2003.0  POWER TRAIN                   0.000000     0.0
#         XVS1100     2005.0                                0.000000     0.0
#         XVS65       2003.0  POWER TRAIN                   0.000000     0.0
#                     2004.0  POWER TRAIN                   0.000000     0.0
# ...
#                             POWER TRAIN                     2600.000000
#         ROAD STAR   2007.0  FUEL SYSTEM                     4200.000000
#                             POWER TRAIN                    53000.000000
#         ROADLINER   2006.0  ENGINE                         29899.000000
#                             POWER TRAIN                    25949.500000
#         STRATOLINER 2006.0  POWER TRAIN                    30000.000000
#         XSR900      2016.0  ELECTRICAL SYSTEM               1200.000000
#         XT1200Z     2013.0  WHEELS                          7300.000000
#         XT250       2015.0  ENGINE                            49.000000
#                             FUEL SYSTEM                       49.000000
#         XTZ12       2013.0  WHEELS                          7300.000000
#         XV1900      2008.0  FUEL SYSTEM                    53000.000000
#         XVS11       2003.0  POWER TRAIN                    50000.000000
#         XVS1100     2005.0                                 40000.000000
#         XVS65       2003.0  POWER TRAIN                    12800.000000
#                     2004.0  POWER TRAIN                    38000.000000
#         XVS950      2014.0  ENGINE                         13000.000000
#         YZF-R3      2015.0  ENGINE                         76831.416194
#                             STEERING                       76831.416194
#                             SUSPENSION                     76831.416194
#         YZF600      2003.0  POWER TRAIN                    19000.000000
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                200.000000
#                             EXTERIOR LIGHTING                200.000000
#         ZERO X      2012.0  FUEL SYSTEM                        1.000000
#
#                                                           OCCURENCES  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                   1.18434
#                             ELECTRICAL SYSTEM                1.18434
#                     1998.0  AIR BAGS                         1.18434
#                     2001.0  POWER TRAIN                      1.18434
#                     2003.0  POWER TRAIN                      1.00000
#         ILX         2013.0  AIR BAGS                         1.18434
#                     2014.0  AIR BAGS                         1.00000
#                     2015.0  AIR BAGS                         1.00000
#                     2016.0  AIR BAGS                         1.18434
#                             ELECTRICAL SYSTEM                1.18434
#                             POWER TRAIN                      1.18434
#                     2017.0  POWER TRAIN                      1.18434
#         INTEGRA     1994.0  VISIBILITY/WIPER                 1.18434
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC        1.18434
#                     1994.0  ELECTRICAL SYSTEM                1.18434
#                             SEATS                            1.18434
#         MDX         2001.0  AIR BAGS                         1.18434
#                             ELECTRONIC STABILITY CONTROL     1.18434
#                             ENGINE                           1.18434
#                             FUEL SYSTEM                      1.18434
#                             POWER TRAIN                      1.18434
#                             SUSPENSION                       1.18434
#                             VEHICLE SPEED CONTROL            1.18434
#                     2002.0  AIR BAGS                         1.18434
#                             ENGINE                           1.18434
#                             POWER TRAIN                      1.18434
#                     2003.0                                   1.18434
#                             AIR BAGS                         1.18434
#                             ELECTRICAL SYSTEM                1.18434
#                             ENGINE                           1.18434
# ...                                                              ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM                1.18434
#                     2005.0  ELECTRICAL SYSTEM                1.18434
#                     2006.0  EXTERIOR LIGHTING                1.18434
#         FZ-09       2015.0  POWER TRAIN                      1.18434
#         FZ09        2014.0  ELECTRICAL SYSTEM                1.18434
#                             ENGINE                           1.18434
#                             POWER TRAIN                      1.18434
#         ROAD STAR   2007.0  FUEL SYSTEM                      1.18434
#                             POWER TRAIN                      1.18434
#         ROADLINER   2006.0  ENGINE                           1.18434
#                             POWER TRAIN                      1.18434
#         STRATOLINER 2006.0  POWER TRAIN                      1.18434
#         XSR900      2016.0  ELECTRICAL SYSTEM                1.18434
#         XT1200Z     2013.0  WHEELS                           1.18434
#         XT250       2015.0  ENGINE                           1.18434
#                             FUEL SYSTEM                      1.18434
#         XTZ12       2013.0  WHEELS                           1.18434
#         XV1900      2008.0  FUEL SYSTEM                      1.18434
#         XVS11       2003.0  POWER TRAIN                      1.18434
#         XVS1100     2005.0                                   1.18434
#         XVS65       2003.0  POWER TRAIN                      1.18434
#                     2004.0  POWER TRAIN                      1.18434
#         XVS950      2014.0  ENGINE                           1.18434
#         YZF-R3      2015.0  ENGINE                           1.18434
#                             STEERING                         1.18434
#                             SUSPENSION                       1.18434
#         YZF600      2003.0  POWER TRAIN                      1.18434
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                1.18434
#                             EXTERIOR LIGHTING                1.18434
#         ZERO X      2012.0  FUEL SYSTEM                      1.18434
#
#                                                           NUM_CYLS  VEH_SPEED  \
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                5.531325   0.000000
#                             ELECTRICAL SYSTEM             5.531325  30.827276
#                     1998.0  AIR BAGS                      5.531325  30.827276
#                     2001.0  POWER TRAIN                   5.531325  30.827276
#                     2003.0  POWER TRAIN                   6.000000  65.000000
#         ILX         2013.0  AIR BAGS                      5.531325  30.827276
#                     2014.0  AIR BAGS                      4.000000  30.827276
#                     2015.0  AIR BAGS                      4.000000  30.827276
#                     2016.0  AIR BAGS                      5.531325  75.000000
#                             ELECTRICAL SYSTEM             5.531325   0.000000
#                             POWER TRAIN                   5.531325  30.000000
#                     2017.0  POWER TRAIN                   5.531325  10.000000
#         INTEGRA     1994.0  VISIBILITY/WIPER              5.531325  35.000000
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC     5.531325  30.827276
#                     1994.0  ELECTRICAL SYSTEM             5.531325  30.827276
#                             SEATS                         5.531325  30.827276
#         MDX         2001.0  AIR BAGS                      5.531325  30.827276
#                             ELECTRONIC STABILITY CONTROL  5.531325  30.827276
#                             ENGINE                        5.531325  30.827276
#                             FUEL SYSTEM                   5.531325  30.827276
#                             POWER TRAIN                   5.531325  45.000000
#                             SUSPENSION                    5.531325  30.827276
#                             VEHICLE SPEED CONTROL         5.531325  30.827276
#                     2002.0  AIR BAGS                      5.531325  40.000000
#                             ENGINE                        5.531325  30.827276
#                             POWER TRAIN                   5.531325   0.000000
#                     2003.0                                5.531325  40.000000
#                             AIR BAGS                      5.531325  52.500000
#                             ELECTRICAL SYSTEM             5.531325  30.827276
#                             ENGINE                        5.531325  60.000000
# ...                                                            ...        ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM             4.000000  30.827276
#                     2005.0  ELECTRICAL SYSTEM             5.531325  20.000000
#                     2006.0  EXTERIOR LIGHTING             5.531325  60.000000
#         FZ-09       2015.0  POWER TRAIN                   5.531325  30.827276
#         FZ09        2014.0  ELECTRICAL SYSTEM             5.531325  30.827276
#                             ENGINE                        5.531325   0.000000
#                             POWER TRAIN                   5.531325  30.827276
#         ROAD STAR   2007.0  FUEL SYSTEM                   5.531325   0.000000
#                             POWER TRAIN                   5.531325  35.000000
#         ROADLINER   2006.0  ENGINE                        5.531325  35.000000
#                             POWER TRAIN                   5.531325  35.000000
#         STRATOLINER 2006.0  POWER TRAIN                   5.531325  35.000000
#         XSR900      2016.0  ELECTRICAL SYSTEM             5.531325   0.000000
#         XT1200Z     2013.0  WHEELS                        5.531325  65.000000
#         XT250       2015.0  ENGINE                        5.531325  10.000000
#                             FUEL SYSTEM                   5.531325  10.000000
#         XTZ12       2013.0  WHEELS                        5.531325  65.000000
#         XV1900      2008.0  FUEL SYSTEM                   5.531325   0.000000
#         XVS11       2003.0  POWER TRAIN                   5.531325  30.827276
#         XVS1100     2005.0                                5.531325  75.000000
#         XVS65       2003.0  POWER TRAIN                   5.531325  15.000000
#                     2004.0  POWER TRAIN                   5.531325  30.000000
#         XVS950      2014.0  ENGINE                        5.531325  40.000000
#         YZF-R3      2015.0  ENGINE                        5.531325  30.827276
#                             STEERING                      5.531325  30.827276
#                             SUSPENSION                    5.531325  30.827276
#         YZF600      2003.0  POWER TRAIN                   5.531325  50.000000
# ZERO    FX          2016.0  ELECTRICAL SYSTEM             5.531325   0.000000
#                             EXTERIOR LIGHTING             5.531325   0.000000
#         ZERO X      2012.0  FUEL SYSTEM                   5.531325  35.000000
#
#                                                           COMPLAINTS
# MAKETXT MODELTXT    YEARTXT COMPDESC
# ACURA   CL          1997.0                                         1
#                             ELECTRICAL SYSTEM                      1
#                     1998.0  AIR BAGS                               1
#                     2001.0  POWER TRAIN                            1
#                     2003.0  POWER TRAIN                            1
#         ILX         2013.0  AIR BAGS                               7
#                     2014.0  AIR BAGS                               8
#                     2015.0  AIR BAGS                               4
#                     2016.0  AIR BAGS                               3
#                             ELECTRICAL SYSTEM                      1
#                             POWER TRAIN                            1
#                     2017.0  POWER TRAIN                            1
#         INTEGRA     1994.0  VISIBILITY/WIPER                       1
#         LEGEND      1990.0  SERVICE BRAKES, HYDRAULIC              1
#                     1994.0  ELECTRICAL SYSTEM                      1
#                             SEATS                                  1
#         MDX         2001.0  AIR BAGS                               1
#                             ELECTRONIC STABILITY CONTROL           1
#                             ENGINE                                 1
#                             FUEL SYSTEM                            1
#                             POWER TRAIN                            2
#                             SUSPENSION                             1
#                             VEHICLE SPEED CONTROL                  1
#                     2002.0  AIR BAGS                               1
#                             ENGINE                                 1
#                             POWER TRAIN                            4
#                     2003.0                                         2
#                             AIR BAGS                               4
#                             ELECTRICAL SYSTEM                      1
#                             ENGINE                                 1
# ...                                                              ...
# YAMAHA  FJR1300     2003.0  ELECTRICAL SYSTEM                      1
#                     2005.0  ELECTRICAL SYSTEM                      1
#                     2006.0  EXTERIOR LIGHTING                      1
#         FZ-09       2015.0  POWER TRAIN                            1
#         FZ09        2014.0  ELECTRICAL SYSTEM                      1
#                             ENGINE                                 2
#                             POWER TRAIN                            1
#         ROAD STAR   2007.0  FUEL SYSTEM                            2
#                             POWER TRAIN                            1
#         ROADLINER   2006.0  ENGINE                                 1
#                             POWER TRAIN                            2
#         STRATOLINER 2006.0  POWER TRAIN                            1
#         XSR900      2016.0  ELECTRICAL SYSTEM                      1
#         XT1200Z     2013.0  WHEELS                                 1
#         XT250       2015.0  ENGINE                                 1
#                             FUEL SYSTEM                            1
#         XTZ12       2013.0  WHEELS                                 1
#         XV1900      2008.0  FUEL SYSTEM                            1
#         XVS11       2003.0  POWER TRAIN                            1
#         XVS1100     2005.0                                         1
#         XVS65       2003.0  POWER TRAIN                            1
#                     2004.0  POWER TRAIN                            1
#         XVS950      2014.0  ENGINE                                 1
#         YZF-R3      2015.0  ENGINE                                 1
#                             STEERING                               1
#                             SUSPENSION                             1
#         YZF600      2003.0  POWER TRAIN                            1
# ZERO    FX          2016.0  ELECTRICAL SYSTEM                      1
#                             EXTERIOR LIGHTING                      1
#         ZERO X      2012.0  FUEL SYSTEM                            1
#
# [18058 rows x 19 columns]

# %% [markdown]
# ## Check which vehicle types exist in the Recalls dataset
#
# Warning: This is the longest step and it will take several minutes

# %%
# Load the recall dataset
rcl_df = load_data_file('RCL', encoding='latin1');
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
# Rename the component field in recalls so it matches complaints
recalled_set = rcl_df.rename(columns = {'COMPNAME':'COMPDESC'})

# Create the set of vehicle types from the recalled dataset.
# Filter out rows with invalid make, model, or year.
# Also filter out any non-vehicles.
recalled_set = recalled_set[(rcl_df['MAKETXT'] != 'UNKNOWN') &
                      (rcl_df['MODELTXT'] != 'UNKNOWN') &
                      (rcl_df['YEARTXT'] > 1900) &
                      (rcl_df['YEARTXT'] < 2020) &
                      (rcl_df['RCLTYPECD'] == 'V')][key_cols].copy()

# Generalize the names of each component
recalled_set['COMPDESC'] = recalled_set['COMPDESC'].apply(split)

# Make the recalled set only have unique vehicle types,
# mostly for efficiency in the next step.
recalled_set = recalled_set[key_cols].groupby(key_cols).size()

# %%
# Create the column in the complaints set which says
# whether a vehicle type is in the recalled set.
grouped_df['RECALLED'] = False
for index, row in grouped_df.iterrows():
    row['RECALLED'] = index in recalled_set.index
    grouped_df.loc[index] = row
    
print('done')
# Out:
# done

# %% [markdown]
# # Random Decision Forest Prediction
#
# ## Import required libraries

# %%
# Import required libraries
from sklearn.preprocessing import LabelEncoder
import random
from sklearn.metrics import roc_curve, auc
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import ensemble
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Prepare data for training and validation

# %%
# Copy the dataset for prediction.
fullData = grouped_df.copy();

# %%
# Drop columns that have missing values. Our previous
# steps would have filled all missing values UNLESS
# the column is entirely filled with null. Therefore,
# just drop columns that are null, they don't tell us anything.
for col in cat_cols + numer_cols:
    if fullData[col].isnull().any():
        print('Dropping column ', col)
        fullData[col].drop(col, axis=1)

# Create label encoders for categorical features
for var in cat_cols:
    number = LabelEncoder()
    fullData[var] = number.fit_transform(fullData[var].astype('str'))

# Target variable is also a categorical so convert it
fullData['RECALLED'] = number.fit_transform(fullData['RECALLED'].astype('str'))

# Split train dataset into train and validation sub-sets
fullData['is_train'] = np.random.uniform(0, 1, len(fullData)) <= .75
Train, Validate = fullData[fullData['is_train']==True], fullData[fullData['is_train']==False]

print('Training set size =', Train.shape[0])
print('Validation set size =', Validate.shape[0])
# Out:
# Training set size = 13549
# Validation set size = 4509

# %%
# Get a list of the defining features.
features = list(set(list(fullData.columns)) - set(['RECALLED']))

x_train = Train[list(features)].values
y_train = Train['RECALLED'].values
x_validate = Validate[list(features)].values
y_validate = Validate['RECALLED'].values
#x_test=test[list(features)].values

# %% [markdown]
# ## Calculate and plot the ROC Curve

# %%
# Create the random forest classifier
random.seed(100)
rf = RandomForestClassifier(n_estimators=1000)
rf.fit(x_train, y_train)

# Predict the probablies of recalls for the validation set.
status = rf.predict_proba(x_validate)

# Calculate the ROC curve and Area under the curve.
fpr, tpr, _ = roc_curve(y_validate, status[:,1])
roc_auc = auc(fpr, tpr)
print('Area under ROC curve =', roc_auc)
# Out:
# Area under ROC curve = 0.659859065033

# %%
# Plot the ROC curve
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Calculate the Confusion Matrix

# %%
# Get a list of the actual recalled states.
y_true = y_validate

# Get a list of the predicted recalled states.
# The status array holds probabilities whether something is recalled
y_pred = np.array([(item[1] >= 0.5) for item in status]).astype(int)

# Calculate the confusion matrix
cnf_matrix = confusion_matrix(y_true, y_pred)

# Print the confusion matrix
print('confusion matrix:')
print(cnf_matrix)

# Now print out what it MEANS:
print()
print(cnf_matrix[0][0], ' non-recalled cars were predicted to be not recalled')
print(cnf_matrix[0][1], ' non-recalled cars were predicted to be recalled')
print(cnf_matrix[1][0], ' recalled cars were predicted to be not recalled')
print(cnf_matrix[1][1], ' recalled cars were predicted to be recalled')
# Out:
# confusion matrix:
# [[3528  215]
#  [ 595  171]]
#
# 3528  non-recalled cars were predicted to be not recalled
# 215  non-recalled cars were predicted to be recalled
# 595  recalled cars were predicted to be not recalled
# 171  recalled cars were predicted to be recalled

# %% [markdown]
# ## Calculate the Accuracy & Mean Squared Error

# %%
print('accuracy =', accuracy_score(y_true, y_pred))
print('Mean squared error =', mean_squared_error(y_true, y_pred))
# Out:
# accuracy = 0.820359281437
# Mean squared error = 0.179640718563
